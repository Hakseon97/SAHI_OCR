# %%
import os
from sahi.utils.yolov8 import (
    download_yolov8s_model, download_yolov8s_seg_model
)

from sahi import AutoDetectionModel
from sahi.utils.cv import read_image
from sahi.utils.file import download_from_url
from sahi.predict import get_prediction, get_sliced_prediction, predict
from IPython.display import Image

# %%
from ultralytics import YOLO
model = YOLO('/models/yolov8s.pt')

# 학습 시작
results = model.train(
   data='configs/data.yaml',
   epochs=100,
   imgsz=640,
   batch=16,
   name='textbox_detection'
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s.pt to 'yolov8s.pt'...
# 100%|██████████| 21.5M/21.5M [00:01<00:00, 15.7MB/s]
# Ultralytics YOLOv8.2.76 🚀 Python-3.9.19 torch-2.4.0+cpu CPU (12th Gen Intel Core(TM) i7-1260P)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=path/to/data.yaml, epochs=100, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=textbox_detection, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/textbox_detection
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/envs/sahi/lib/python3.9/site-packages/ultralytics/engine/trainer.py:529, in BaseTrainer.get_dataset(self)
#     523 elif self.args.data.split(".")[-1] in {"yaml", "yml"} or self.args.task in {
#     524     "detect",
#     525     "segment",
#     526     "pose",
#     527     "obb",
#     528 }:
# --> 529     data = check_det_dataset(self.args.data)
#     530     if "yaml_file" in data:
#
# File ~/miniconda3/envs/sahi/lib/python3.9/site-packages/ultralytics/data/utils.py:269, in check_det_dataset(dataset, autodownload)
#     254 """
#     255 Download, verify, and/or unzip a dataset if not found locally.
#     256
#    (...)
#     266     (dict): Parsed dataset information and paths.
#     267 """
# --> 269 file = check_file(dataset)
#     271 # Download (optional)
#
# File ~/miniconda3/envs/sahi/lib/python3.9/site-packages/ultralytics/utils/checks.py:509, in check_file(file, suffix, download, download_dir, hard)
#     508 if not files and hard:
# --> 509     raise FileNotFoundError(f"'{file}' does not exist")
#     510 elif len(files) > 1 and hard:
#
# FileNotFoundError: 'path/to/data.yaml' does not exist
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 5
#       2 model = YOLO('yolov8s.pt')
#       4 # 학습 시작
# ----> 5 results = model.train(
#       6    data='path/to/data.yaml',
#       7    epochs=100,
#       8    imgsz=640,
#       9    batch=16,
#      10    name='textbox_detection'
#      11 )
#
# File ~/miniconda3/envs/sahi/lib/python3.9/site-packages/ultralytics/engine/model.py:805, in Model.train(self, trainer, **kwargs)
#     802 if args.get("resume"):
#     803     args["resume"] = self.ckpt_path
# --> 805 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     806 if not args.get("resume"):  # manually set model only if not resuming
#     807     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File ~/miniconda3/envs/sahi/lib/python3.9/site-packages/ultralytics/engine/trainer.py:134, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     132 self.model = check_model_file_from_stem(self.args.model)  # add suffix, i.e. yolov8n -> yolov8n.pt
#     133 with torch_distributed_zero_first(LOCAL_RANK):  # avoid auto-downloading dataset multiple times
# --> 134     self.trainset, self.testset = self.get_dataset()
#     135 self.ema = None
#     137 # Optimization utils init
#
# File ~/miniconda3/envs/sahi/lib/python3.9/site-packages/ultralytics/engine/trainer.py:533, in BaseTrainer.get_dataset(self)
#     531             self.args.data = data["yaml_file"]  # for validating 'yolo train data=url.zip' usage
#     532 except Exception as e:
# --> 533     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
#     534 self.data = data
#     535 return data["train"], data.get("val") or data.get("test")
#
# RuntimeError: Dataset 'path/to/data.yaml' error ❌ 'path/to/data.yaml' does not exist
